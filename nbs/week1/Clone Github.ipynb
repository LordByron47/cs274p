# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# 'CS 247P - Introduction Part 2.gslides'  'CS 274P - Introdcution.gslides'
#  cs274p

# %%
! git clone https://github.com/isakbosman/cs274p
# Out:
# Cloning into 'cs274p'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 40 (delta 12), reused 31 (delta 8), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %%
# !ls 'gdrive/My Drive'
# Out:
# ls: cannot access 'gdrive/My Drive': No such file or directory

# %%
# !mv cs274p gdrive/
# Out:
# mv: cannot create directory 'gdrive/cs274p': Operation not supported

# %%
# %cd gdrive/My Drive/UCI
# Out:
# /content/gdrive/My Drive/UCI

# %%
# !ls
# Out:
# 'CS 247P - Introduction Part 2.gslides'
#  cs274p
# 'CS 274P - Data in Deep Learning.gslides'
# 'CS 274P - Data in Deep Learning Part 2.gslides'
# 'CS 274P - Introduction.gslides'

# %%
! git clone https://github.com/isakbosman/cs274p
# Out:
# Cloning into 'cs274p'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 40 (delta 12), reused 31 (delta 8), pack-reused 0
# Unpacking objects: 100% (40/40), done.

# %%
cd cs274p
# Out:
# /content/gdrive/My Drive/UCI/cs274p

# %%
ls
# Out:
# code/  data/  images/  nbs/  README.md  requirements.txt

# %%
! git add . && git commit -a -m "Updated notebooks after week 2" && git push origin master
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@360c56043fbd.(none)')
